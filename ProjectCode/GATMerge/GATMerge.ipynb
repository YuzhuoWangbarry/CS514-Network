# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import dgl
from dgl.nn.pytorch import edge_softmax
import dgl.function as fn
import dgl.data
from dgl.nn.pytorch import GATConv

def l0_train(logAlpha, beta=0.66, gamma=-0.1, zeta=1.1, eps=1e-20):
    U = torch.rand(logAlpha.size()).type_as(logAlpha) + eps
    s = torch.sigmoid((torch.log(U / (1 - U)) + logAlpha) / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, 0, 1)
    return mask

def l0_test(logAlpha, beta=0.66, gamma=-0.1, zeta=1.1):
    s = torch.sigmoid(logAlpha / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, 0, 1)
    return mask

# Merged GAT Layer
class MergedGATLayer(nn.Module):
    def __init__(self, in_dim, out_dim, num_heads, dropout, alpha, bias_l0, residual=False):
        super(MergedGATLayer, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.num_heads = num_heads
        self.dropout = dropout
        self.leaky_relu = nn.LeakyReLU(alpha)

        self.residual = residual
        if self.residual and in_dim != (out_dim * num_heads):
            self.res_fc = nn.Linear(in_dim, out_dim * num_heads, bias=False)
        else:
            self.res_fc = None

        self.lin_l = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        self.lin_r = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        
        self.att = nn.Parameter(torch.Tensor(1, num_heads, out_dim))
        self.bias_l0 = nn.Parameter(torch.FloatTensor([bias_l0]))
        self.beta = 0.66
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_normal_(self.lin_l.weight)
        nn.init.xavier_normal_(self.lin_r.weight)
        nn.init.xavier_normal_(self.att)

    def forward(self, g, inputs):
        if inputs.dim() != 2:
            raise ValueError("Expected 2D input tensor, but got {}D".format(inputs.dim()))

        num_nodes = inputs.shape[0]
        new_feature_size = self.out_dim * self.num_heads  # Assuming out_dim is defined in __init__

        h_l = F.dropout(self.lin_l(inputs), p=self.dropout, training=self.training)
        h_r = F.dropout(self.lin_r(inputs), p=self.dropout, training=self.training)

        # Ensure that the total size matches before reshaping
        if h_l.numel() != num_nodes * new_feature_size or h_r.numel() != num_nodes * new_feature_size:
            raise RuntimeError("Mismatch in total elements for reshaping.")

        h_l = h_l.view(num_nodes, self.num_heads, -1)
        h_r = h_r.view(num_nodes, self.num_heads, -1)

        g.ndata['h_l'] = h_l
        g.ndata['h_r'] = h_r

        # Compute attention scores
        g.apply_edges(self.edge_attention)
        
        # Apply edge softmax to normalize attention scores
        g.edata['a'] = edge_softmax(g, g.edata['a'])

        g.update_all(fn.u_mul_e('h_r', 'a', 'm'), fn.sum('m', 'h'))
        h = g.ndata.pop('h').view(inputs.shape[0], -1)

        # Apply residual connection
        if self.residual:
            if self.res_fc is not None:
                res_out = self.res_fc(inputs)
            else:
                res_out = inputs
            h += res_out 

        return h      
        return h

    def edge_attention(self, edges):
        # GATv2 dynamic attention mechanism
        h_l = edges.src['h_l']
        h_r = edges.dst['h_r']
        e = self.leaky_relu(h_l + h_r)
        alpha = (e * self.att).sum(dim=-1, keepdim=True)

        alpha = alpha + self.bias_l0
        if self.training:
            alpha = l0_train(alpha, beta=self.beta)
        else:
            alpha = l0_test(alpha, beta=self.beta)

        return {'a': alpha}


class MergedGAT(nn.Module):
    def __init__(self, g, in_dim, num_hidden, num_classes, num_heads, dropout, alpha, bias_l0):
        super(MergedGAT, self).__init__()
        self.dropout = dropout
        self.num_classes = num_classes
        self.graph = g

  
        self.layers = nn.ModuleList([
            MergedGATLayer(in_dim, num_hidden, num_heads, dropout, alpha, bias_l0, residual=True)
        ])

        # Intermediate layers
        for _ in range(3):
            self.layers.append(MergedGATLayer(num_hidden * num_heads, num_hidden, num_heads, dropout, alpha, bias_l0, residual=True))

        # Final layer
        self.layers.append(MergedGATLayer(num_hidden * num_heads, num_classes, 1, dropout, alpha, bias_l0, residual=True))

    def forward(self, inputs):
        h = inputs
        for i, layer in enumerate(self.layers):
            h = layer(self.graph, h)
            if i < len(self.layers) - 1:
                h = F.elu(h)
                h = F.dropout(h, p=self.dropout, training=self.training)
            else:
                h = h.view(h.shape[0], -1)
                h = h[:, :self.num_classes]
        return h

# %%
def load_cora_data():
    dataset = dgl.data.CoraGraphDataset()
    g = dataset[0]
    g = dgl.remove_self_loop(g)
    g = dgl.add_self_loop(g)
    degs = g.in_degrees().float()
    norm = torch.pow(degs, -0.5)
    norm[torch.isinf(norm)] = 0
    g.ndata['norm'] = norm.unsqueeze(1)

    return g, dataset.num_classes

# %%
def train_model(g, num_classes):
    # Hyperparameters
    num_heads = 8
    num_hidden = 256
    dropout = 0.6
    alpha = 0.2
    bias_l0 = 0.1
    in_dim = g.ndata['feat'].shape[1]
    
    model = model = MergedGAT(g, in_dim=1433, num_hidden=256, num_classes=num_classes, num_heads=8, dropout=0.6, alpha=0.2, bias_l0=0.1)

    loss_func = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0005)

    for epoch in range(100):
        model.train()
        logits = model(g.ndata['feat'])
        loss = loss_func(logits[g.ndata['train_mask']], g.ndata['label'][g.ndata['train_mask']])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate training accuracy
        _, train_indices = torch.max(logits, dim=1)
        train_correct = torch.sum(train_indices[g.ndata['train_mask']] == g.ndata['label'][g.ndata['train_mask']])
        train_accuracy = float(train_correct) / int(g.ndata['train_mask'].sum())

        # Evaluate on validation set
        model.eval()
        with torch.no_grad():
            val_logits = model(g.ndata['feat'])
            val_loss = loss_func(val_logits[g.ndata['val_mask']], g.ndata['label'][g.ndata['val_mask']])
            _, val_indices = torch.max(val_logits, dim=1)
            val_correct = torch.sum(val_indices[g.ndata['val_mask']] == g.ndata['label'][g.ndata['val_mask']])
            val_accuracy = float(val_correct) / int(g.ndata['val_mask'].sum())

        print(f"Epoch {epoch:05d} | Train Loss {loss.item():.4f} | Train Accuracy {train_accuracy:.4f} | Val Loss {val_loss.item():.4f} | Val Accuracy {val_accuracy:.4f}")

# %%
g, num_classes = load_cora_data()
train_model(g, num_classes)
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# Epoch 00000 | Train Loss 1.9493 | Train Accuracy 0.1071 | Val Loss 1.9130 | Val Accuracy 0.3280
# Epoch 00001 | Train Loss 1.9130 | Train Accuracy 0.3071 | Val Loss 1.8718 | Val Accuracy 0.3880
# Epoch 00002 | Train Loss 1.8434 | Train Accuracy 0.4571 | Val Loss 1.8224 | Val Accuracy 0.4280
# Epoch 00003 | Train Loss 1.7498 | Train Accuracy 0.5500 | Val Loss 1.7599 | Val Accuracy 0.4540
# Epoch 00004 | Train Loss 1.6527 | Train Accuracy 0.5714 | Val Loss 1.6732 | Val Accuracy 0.5420
# Epoch 00005 | Train Loss 1.5253 | Train Accuracy 0.6786 | Val Loss 1.5549 | Val Accuracy 0.6280
# Epoch 00006 | Train Loss 1.3521 | Train Accuracy 0.7500 | Val Loss 1.3995 | Val Accuracy 0.6920
# Epoch 00007 | Train Loss 1.1766 | Train Accuracy 0.8071 | Val Loss 1.2170 | Val Accuracy 0.7400
# Epoch 00008 | Train Loss 0.9830 | Train Accuracy 0.8071 | Val Loss 1.0407 | Val Accuracy 0.7300
# Epoch 00009 | Train Loss 0.7724 | Train Accuracy 0.8429 | Val Loss 0.8996 | Val Accuracy 0.7360
# Epoch 00010 | Train Loss 0.6898 | Train Accuracy 0.7500 | Val Loss 0.7952 | Val Accuracy 0.7480
# Epoch 00011 | Train Loss 0.5297 | Train Accuracy 0.8357 | Val Loss 0.7182 | Val Accuracy 0.7680
# Epoch 00012 | Train Loss 0.4706 | Train Accuracy 0.8214 | Val Loss 0.6557 | Val Accuracy 0.7940
# Epoch 00013 | Train Loss 0.4188 | Train Accuracy 0.8571 | Val Loss 0.6256 | Val Accuracy 0.8080
# Epoch 00014 | Train Loss 0.3630 | Train Accuracy 0.8714 | Val Loss 0.6418 | Val Accuracy 0.8100
# Epoch 00015 | Train Loss 0.3652 | Train Accuracy 0.8571 | Val Loss 0.6941 | Val Accuracy 0.8060
# Epoch 00016 | Train Loss 0.1851 | Train Accuracy 0.9286 | Val Loss 0.7667 | Val Accuracy 0.7980
# Epoch 00017 | Train Loss 0.2061 | Train Accuracy 0.9143 | Val Loss 0.8383 | Val Accuracy 0.7980
# Epoch 00018 | Train Loss 0.1804 | Train Accuracy 0.9357 | Val Loss 0.9254 | Val Accuracy 0.7980
# Epoch 00019 | Train Loss 0.1564 | Train Accuracy 0.9571 | Val Loss 0.9887 | Val Accuracy 0.7920
# Epoch 00020 | Train Loss 0.1112 | Train Accuracy 0.9643 | Val Loss 1.0554 | Val Accuracy 0.7980
# Epoch 00021 | Train Loss 0.0925 | Train Accuracy 0.9643 | Val Loss 1.1049 | Val Accuracy 0.7960
# Epoch 00022 | Train Loss 0.0723 | Train Accuracy 0.9643 | Val Loss 1.1666 | Val Accuracy 0.7960
# Epoch 00023 | Train Loss 0.0767 | Train Accuracy 0.9786 | Val Loss 1.2198 | Val Accuracy 0.7980
# Epoch 00024 | Train Loss 0.0742 | Train Accuracy 0.9714 | Val Loss 1.2658 | Val Accuracy 0.7900
# Epoch 00025 | Train Loss 0.0884 | Train Accuracy 0.9714 | Val Loss 1.3541 | Val Accuracy 0.7900
# Epoch 00026 | Train Loss 0.0741 | Train Accuracy 0.9786 | Val Loss 1.4766 | Val Accuracy 0.7800
# Epoch 00027 | Train Loss 0.0500 | Train Accuracy 0.9929 | Val Loss 1.5869 | Val Accuracy 0.7760
# Epoch 00028 | Train Loss 0.0707 | Train Accuracy 0.9786 | Val Loss 1.7225 | Val Accuracy 0.7700
# Epoch 00029 | Train Loss 0.0277 | Train Accuracy 1.0000 | Val Loss 1.8347 | Val Accuracy 0.7720
# Epoch 00030 | Train Loss 0.0469 | Train Accuracy 0.9786 | Val Loss 1.8414 | Val Accuracy 0.7700
# Epoch 00031 | Train Loss 0.0272 | Train Accuracy 0.9857 | Val Loss 1.8472 | Val Accuracy 0.7620
# Epoch 00032 | Train Loss 0.0375 | Train Accuracy 0.9929 | Val Loss 1.8305 | Val Accuracy 0.7680
# Epoch 00033 | Train Loss 0.0280 | Train Accuracy 0.9786 | Val Loss 1.7972 | Val Accuracy 0.7700
# Epoch 00034 | Train Loss 0.0268 | Train Accuracy 0.9929 | Val Loss 1.7765 | Val Accuracy 0.7780
# Epoch 00035 | Train Loss 0.0187 | Train Accuracy 0.9929 | Val Loss 1.7762 | Val Accuracy 0.7820
# Epoch 00036 | Train Loss 0.0170 | Train Accuracy 1.0000 | Val Loss 1.7848 | Val Accuracy 0.7760
# Epoch 00037 | Train Loss 0.0159 | Train Accuracy 1.0000 | Val Loss 1.8197 | Val Accuracy 0.7760
# Epoch 00038 | Train Loss 0.0162 | Train Accuracy 1.0000 | Val Loss 1.8560 | Val Accuracy 0.7720
# Epoch 00039 | Train Loss 0.0144 | Train Accuracy 1.0000 | Val Loss 1.9058 | Val Accuracy 0.7700
# Epoch 00040 | Train Loss 0.0157 | Train Accuracy 1.0000 | Val Loss 1.9605 | Val Accuracy 0.7660
# Epoch 00041 | Train Loss 0.0093 | Train Accuracy 1.0000 | Val Loss 1.9987 | Val Accuracy 0.7640
# Epoch 00042 | Train Loss 0.0140 | Train Accuracy 1.0000 | Val Loss 2.0125 | Val Accuracy 0.7600
# Epoch 00043 | Train Loss 0.0181 | Train Accuracy 0.9929 | Val Loss 2.0254 | Val Accuracy 0.7640
# Epoch 00044 | Train Loss 0.0192 | Train Accuracy 0.9929 | Val Loss 1.9854 | Val Accuracy 0.7640
# Epoch 00045 | Train Loss 0.0107 | Train Accuracy 1.0000 | Val Loss 1.9436 | Val Accuracy 0.7700
# Epoch 00046 | Train Loss 0.0082 | Train Accuracy 1.0000 | Val Loss 1.8993 | Val Accuracy 0.7700
# Epoch 00047 | Train Loss 0.0091 | Train Accuracy 1.0000 | Val Loss 1.8556 | Val Accuracy 0.7780
# Epoch 00048 | Train Loss 0.0152 | Train Accuracy 0.9929 | Val Loss 1.8514 | Val Accuracy 0.7860
# Epoch 00049 | Train Loss 0.0039 | Train Accuracy 1.0000 | Val Loss 1.8556 | Val Accuracy 0.7880
# Epoch 00050 | Train Loss 0.0047 | Train Accuracy 1.0000 | Val Loss 1.8697 | Val Accuracy 0.7860
# Epoch 00051 | Train Loss 0.0082 | Train Accuracy 0.9929 | Val Loss 1.8887 | Val Accuracy 0.7820
# Epoch 00052 | Train Loss 0.0051 | Train Accuracy 1.0000 | Val Loss 1.9049 | Val Accuracy 0.7760
# Epoch 00053 | Train Loss 0.0155 | Train Accuracy 0.9929 | Val Loss 1.9389 | Val Accuracy 0.7660
# Epoch 00054 | Train Loss 0.0071 | Train Accuracy 1.0000 | Val Loss 1.9772 | Val Accuracy 0.7600
# Epoch 00055 | Train Loss 0.0063 | Train Accuracy 1.0000 | Val Loss 1.9951 | Val Accuracy 0.7540
# Epoch 00056 | Train Loss 0.0101 | Train Accuracy 1.0000 | Val Loss 1.9803 | Val Accuracy 0.7500
# Epoch 00057 | Train Loss 0.0318 | Train Accuracy 0.9929 | Val Loss 1.9258 | Val Accuracy 0.7600
# Epoch 00058 | Train Loss 0.0051 | Train Accuracy 1.0000 | Val Loss 1.8667 | Val Accuracy 0.7640
# Epoch 00059 | Train Loss 0.0036 | Train Accuracy 1.0000 | Val Loss 1.8183 | Val Accuracy 0.7720
# Epoch 00060 | Train Loss 0.0138 | Train Accuracy 0.9929 | Val Loss 1.7523 | Val Accuracy 0.7740
# Epoch 00061 | Train Loss 0.0195 | Train Accuracy 0.9857 | Val Loss 1.7078 | Val Accuracy 0.7760
# Epoch 00062 | Train Loss 0.0049 | Train Accuracy 1.0000 | Val Loss 1.6811 | Val Accuracy 0.7740
# Epoch 00063 | Train Loss 0.0036 | Train Accuracy 1.0000 | Val Loss 1.6710 | Val Accuracy 0.7680
# Epoch 00064 | Train Loss 0.0080 | Train Accuracy 1.0000 | Val Loss 1.6710 | Val Accuracy 0.7600
# Epoch 00065 | Train Loss 0.0128 | Train Accuracy 1.0000 | Val Loss 1.6591 | Val Accuracy 0.7600
# Epoch 00066 | Train Loss 0.0204 | Train Accuracy 0.9857 | Val Loss 1.6063 | Val Accuracy 0.7700
# Epoch 00067 | Train Loss 0.0095 | Train Accuracy 1.0000 | Val Loss 1.5620 | Val Accuracy 0.7760
# Epoch 00068 | Train Loss 0.0076 | Train Accuracy 1.0000 | Val Loss 1.5524 | Val Accuracy 0.7800
# Epoch 00069 | Train Loss 0.0075 | Train Accuracy 1.0000 | Val Loss 1.5581 | Val Accuracy 0.7800
# Epoch 00070 | Train Loss 0.0119 | Train Accuracy 0.9929 | Val Loss 1.5661 | Val Accuracy 0.7820
# Epoch 00071 | Train Loss 0.0116 | Train Accuracy 1.0000 | Val Loss 1.5523 | Val Accuracy 0.7800
# Epoch 00072 | Train Loss 0.0390 | Train Accuracy 0.9857 | Val Loss 1.5375 | Val Accuracy 0.7780
# Epoch 00073 | Train Loss 0.0054 | Train Accuracy 1.0000 | Val Loss 1.5510 | Val Accuracy 0.7640
# Epoch 00074 | Train Loss 0.0057 | Train Accuracy 1.0000 | Val Loss 1.5803 | Val Accuracy 0.7680
# Epoch 00075 | Train Loss 0.0268 | Train Accuracy 0.9786 | Val Loss 1.5368 | Val Accuracy 0.7660
# Epoch 00076 | Train Loss 0.0140 | Train Accuracy 0.9929 | Val Loss 1.4676 | Val Accuracy 0.7660
# Epoch 00077 | Train Loss 0.0041 | Train Accuracy 1.0000 | Val Loss 1.4087 | Val Accuracy 0.7760
# Epoch 00078 | Train Loss 0.0063 | Train Accuracy 1.0000 | Val Loss 1.3636 | Val Accuracy 0.7780
# Epoch 00079 | Train Loss 0.0056 | Train Accuracy 1.0000 | Val Loss 1.3351 | Val Accuracy 0.7800
# Epoch 00080 | Train Loss 0.0108 | Train Accuracy 0.9929 | Val Loss 1.3262 | Val Accuracy 0.7820
# Epoch 00081 | Train Loss 0.0075 | Train Accuracy 1.0000 | Val Loss 1.3233 | Val Accuracy 0.7800
# Epoch 00082 | Train Loss 0.0091 | Train Accuracy 0.9929 | Val Loss 1.3195 | Val Accuracy 0.7760
# Epoch 00083 | Train Loss 0.0185 | Train Accuracy 0.9857 | Val Loss 1.3235 | Val Accuracy 0.7780
# Epoch 00084 | Train Loss 0.0089 | Train Accuracy 1.0000 | Val Loss 1.3227 | Val Accuracy 0.7780
# Epoch 00085 | Train Loss 0.0094 | Train Accuracy 1.0000 | Val Loss 1.3241 | Val Accuracy 0.7780
# Epoch 00086 | Train Loss 0.0108 | Train Accuracy 0.9929 | Val Loss 1.3318 | Val Accuracy 0.7740
# Epoch 00087 | Train Loss 0.0212 | Train Accuracy 0.9857 | Val Loss 1.3241 | Val Accuracy 0.7760
# Epoch 00088 | Train Loss 0.0069 | Train Accuracy 1.0000 | Val Loss 1.3155 | Val Accuracy 0.7800
# Epoch 00089 | Train Loss 0.0072 | Train Accuracy 1.0000 | Val Loss 1.3048 | Val Accuracy 0.7760
# Epoch 00090 | Train Loss 0.0062 | Train Accuracy 1.0000 | Val Loss 1.2939 | Val Accuracy 0.7720
# Epoch 00091 | Train Loss 0.0084 | Train Accuracy 1.0000 | Val Loss 1.2758 | Val Accuracy 0.7760
# Epoch 00092 | Train Loss 0.0057 | Train Accuracy 1.0000 | Val Loss 1.2579 | Val Accuracy 0.7760
# Epoch 00093 | Train Loss 0.0098 | Train Accuracy 1.0000 | Val Loss 1.2431 | Val Accuracy 0.7760
# Epoch 00094 | Train Loss 0.0055 | Train Accuracy 1.0000 | Val Loss 1.2286 | Val Accuracy 0.7780
# Epoch 00095 | Train Loss 0.0072 | Train Accuracy 1.0000 | Val Loss 1.2128 | Val Accuracy 0.7760
# Epoch 00096 | Train Loss 0.0074 | Train Accuracy 1.0000 | Val Loss 1.1958 | Val Accuracy 0.7760
# Epoch 00097 | Train Loss 0.0055 | Train Accuracy 1.0000 | Val Loss 1.1798 | Val Accuracy 0.7760
# Epoch 00098 | Train Loss 0.0062 | Train Accuracy 1.0000 | Val Loss 1.1645 | Val Accuracy 0.7780
# Epoch 00099 | Train Loss 0.0095 | Train Accuracy 1.0000 | Val Loss 1.1530 | Val Accuracy 0.7760
