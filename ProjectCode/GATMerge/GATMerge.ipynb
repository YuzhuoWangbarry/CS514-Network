# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import dgl
from dgl.nn.pytorch import edge_softmax
import dgl.function as fn
import dgl.data
from dgl.nn.pytorch import GATConv

def l0_train(logAlpha, beta=0.66, gamma=-0.1, zeta=1.1, eps=1e-20):
    U = torch.rand(logAlpha.size()).type_as(logAlpha) + eps
    s = torch.sigmoid((torch.log(U / (1 - U)) + logAlpha) / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, 0, 1)
    return mask

def l0_test(logAlpha, beta=0.66, gamma=-0.1, zeta=1.1):
    s = torch.sigmoid(logAlpha / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, 0, 1)
    return mask

class MergedGATLayer(nn.Module):
    def __init__(self, in_dim, out_dim, num_heads, dropout, alpha, bias_l0, residual=False):
        super(MergedGATLayer, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.num_heads = num_heads
        self.dropout = dropout
        self.leaky_relu = nn.LeakyReLU(alpha)

        self.residual = residual
        if self.residual and in_dim != (out_dim * num_heads):
            self.res_fc = nn.Linear(in_dim, out_dim * num_heads, bias=False)
        else:
            self.res_fc = None

        self.lin_l = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        self.lin_r = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        
        self.att = nn.Parameter(torch.Tensor(1, num_heads, out_dim))
        self.bias_l0 = nn.Parameter(torch.FloatTensor([bias_l0]))
        self.beta = 0.66
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_normal_(self.lin_l.weight)
        nn.init.xavier_normal_(self.lin_r.weight)
        nn.init.xavier_normal_(self.att)

    def forward(self, g, inputs):
        if inputs.dim() != 2:
            raise ValueError("Expected 2D input tensor, but got {}D".format(inputs.dim()))

        num_nodes = inputs.shape[0]
        new_feature_size = self.out_dim * self.num_heads  # Assuming out_dim is defined in __init__

        h_l = F.dropout(self.lin_l(inputs), p=self.dropout, training=self.training)
        h_r = F.dropout(self.lin_r(inputs), p=self.dropout, training=self.training)

        # Ensure that the total size matches before reshaping
        if h_l.numel() != num_nodes * new_feature_size or h_r.numel() != num_nodes * new_feature_size:
            raise RuntimeError("Mismatch in total elements for reshaping.")

        h_l = h_l.view(num_nodes, self.num_heads, -1)
        h_r = h_r.view(num_nodes, self.num_heads, -1)

        g.ndata['h_l'] = h_l
        g.ndata['h_r'] = h_r

        # Compute attention scores
        g.apply_edges(self.edge_attention)
        
        # Apply edge softmax to normalize attention scores
        g.edata['a'] = edge_softmax(g, g.edata['a'])

        g.update_all(fn.u_mul_e('h_r', 'a', 'm'), fn.sum('m', 'h'))
        h = g.ndata.pop('h').view(inputs.shape[0], -1)

        if self.residual:
            if self.res_fc is not None:
                res_out = self.res_fc(inputs)
            else:
                res_out = inputs
            h += res_out 

        return h      
        return h

    def edge_attention(self, edges):
        h_l = edges.src['h_l']
        h_r = edges.dst['h_r']
        e = self.leaky_relu(h_l + h_r)
        alpha = (e * self.att).sum(dim=-1, keepdim=True)

        alpha = alpha + self.bias_l0
        if self.training:
            alpha = l0_train(alpha, beta=self.beta)
        else:
            alpha = l0_test(alpha, beta=self.beta)

        return {'a': alpha}


class MergedGAT(nn.Module):
    def __init__(self, g, in_dim, num_hidden, num_classes, num_heads, dropout, alpha, bias_l0):
        super(MergedGAT, self).__init__()
        self.dropout = dropout
        self.num_classes = num_classes
        self.graph = g

  
        self.layers = nn.ModuleList([
            MergedGATLayer(in_dim, num_hidden, num_heads, dropout, alpha, bias_l0, residual=True)
        ])

        # Intermediate layers
        for _ in range(0):
            self.layers.append(MergedGATLayer(num_hidden * num_heads, num_hidden, num_heads, dropout, alpha, bias_l0, residual=True))

        # Final layer
        self.layers.append(MergedGATLayer(num_hidden * num_heads, num_classes, 1, dropout, alpha, bias_l0, residual=True))

    def forward(self, inputs):
        h = inputs
        for i, layer in enumerate(self.layers):
            h = layer(self.graph, h)
            if i < len(self.layers) - 1:
                h = F.elu(h)
                h = F.dropout(h, p=self.dropout, training=self.training)
            else:
                h = h.view(h.shape[0], -1)
                h = h[:, :self.num_classes]
        return h

# %%
import csv
def train_model(g, num_classes):
    # Hyperparameters
    num_heads = 8
    num_hidden = 256
    dropout = 0.6
    alpha = 0.2
    bias_l0 = 0.1
    in_dim = g.ndata['feat'].shape[1]
    print(in_dim)
    model = model = MergedGAT(g, in_dim=in_dim, num_hidden=256, num_classes=num_classes, num_heads=8, dropout=0.6, alpha=0.2, bias_l0=0.1)

    loss_func = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0005)
    file = open('GAT_Merge.csv', 'w', newline='')
    writer = csv.writer(file)
    writer.writerow(['Epoch', 'Loss', 'Train Accuracy', 'Test Accuracy'])
    for epoch in range(100):
        model.train()
        logits = model(g.ndata['feat'])
        loss = loss_func(logits[g.ndata['train_mask']], g.ndata['label'][g.ndata['train_mask']])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate training accuracy
        _, train_indices = torch.max(logits, dim=1)
        train_correct = torch.sum(train_indices[g.ndata['train_mask']] == g.ndata['label'][g.ndata['train_mask']])
        train_accuracy = float(train_correct) / int(g.ndata['train_mask'].sum())

        # Evaluate on validation set
        model.eval()
        with torch.no_grad():
            val_logits = model(g.ndata['feat'])
            val_loss = loss_func(val_logits[g.ndata['val_mask']], g.ndata['label'][g.ndata['val_mask']])
            _, val_indices = torch.max(val_logits, dim=1)
            val_correct = torch.sum(val_indices[g.ndata['val_mask']] == g.ndata['label'][g.ndata['val_mask']])
            val_accuracy = float(val_correct) / int(g.ndata['val_mask'].sum())
        writer.writerow([epoch, loss.item(), train_accuracy, val_accuracy])
        print(f"Epoch {epoch:05d} | Train Loss {loss.item():.4f} | Train Accuracy {train_accuracy:.4f} | Val Loss {val_loss.item():.4f} | Val Accuracy {val_accuracy:.4f}")

# %%
def load_cora_data():
    dataset = dgl.data.CoraGraphDataset()
    g = dataset[0]
    g = dgl.remove_self_loop(g)
    g = dgl.add_self_loop(g)
    degs = g.in_degrees().float()
    norm = torch.pow(degs, -0.5)
    norm[torch.isinf(norm)] = 0
    g.ndata['norm'] = norm.unsqueeze(1)

    return g, dataset.num_classes

# %%
import dgl
from torch_geometric.datasets import Amazon
from torch_geometric.utils import to_networkx
from torch_geometric.transforms import RandomNodeSplit

def load_amazon_computers_data():
    dataset = Amazon(root='/tmp/Amazon', name='Computers')
    transform = RandomNodeSplit(split='random', num_train_per_class=20, num_val=500, num_test=1000)
    data = transform(dataset[0])
    g = dgl.from_networkx(to_networkx(data))
    g.ndata['feat'] = data.x
    g.ndata['label'] = data.y
    g.ndata['train_mask'] = data.train_mask
    g.ndata['val_mask'] = data.val_mask
    g.ndata['test_mask'] = data.test_mask

    return g, dataset.num_classes

# %%
g, num_classes = load_amazon_computers_data()
train_model(g, num_classes)
# Out:
# 767
# Epoch 00000 | Train Loss 2.7343 | Train Accuracy 0.0800 | Val Loss 13.0030 | Val Accuracy 0.0260
# Epoch 00001 | Train Loss 10.4398 | Train Accuracy 0.1200 | Val Loss 13.6720 | Val Accuracy 0.0440
# Epoch 00002 | Train Loss 11.4298 | Train Accuracy 0.1300 | Val Loss 11.7585 | Val Accuracy 0.2020
# Epoch 00003 | Train Loss 11.0112 | Train Accuracy 0.2150 | Val Loss 10.3658 | Val Accuracy 0.0960
# Epoch 00004 | Train Loss 11.0546 | Train Accuracy 0.1800 | Val Loss 5.7836 | Val Accuracy 0.2360
# Epoch 00005 | Train Loss 7.9592 | Train Accuracy 0.2400 | Val Loss 7.0214 | Val Accuracy 0.4100
# Epoch 00006 | Train Loss 9.4434 | Train Accuracy 0.1100 | Val Loss 3.7217 | Val Accuracy 0.4280
# Epoch 00007 | Train Loss 5.1763 | Train Accuracy 0.2150 | Val Loss 5.1899 | Val Accuracy 0.0880
# Epoch 00008 | Train Loss 5.7541 | Train Accuracy 0.2400 | Val Loss 7.4853 | Val Accuracy 0.1560
# Epoch 00009 | Train Loss 5.6849 | Train Accuracy 0.2450 | Val Loss 8.8706 | Val Accuracy 0.1720
# Epoch 00010 | Train Loss 6.4000 | Train Accuracy 0.2000 | Val Loss 8.3734 | Val Accuracy 0.2720
# Epoch 00011 | Train Loss 5.2135 | Train Accuracy 0.2700 | Val Loss 7.7917 | Val Accuracy 0.3200
# Epoch 00012 | Train Loss 4.6540 | Train Accuracy 0.3450 | Val Loss 8.1641 | Val Accuracy 0.2320
# Epoch 00013 | Train Loss 4.0563 | Train Accuracy 0.3750 | Val Loss 8.0355 | Val Accuracy 0.2060
# Epoch 00014 | Train Loss 3.8092 | Train Accuracy 0.3900 | Val Loss 7.3467 | Val Accuracy 0.2080
# Epoch 00015 | Train Loss 3.1984 | Train Accuracy 0.4350 | Val Loss 6.9222 | Val Accuracy 0.1820
# Epoch 00016 | Train Loss 3.1706 | Train Accuracy 0.4450 | Val Loss 6.4077 | Val Accuracy 0.1460
# Epoch 00017 | Train Loss 3.0580 | Train Accuracy 0.3950 | Val Loss 5.2122 | Val Accuracy 0.2420
# Epoch 00018 | Train Loss 2.4638 | Train Accuracy 0.4750 | Val Loss 4.1790 | Val Accuracy 0.2840
# Epoch 00019 | Train Loss 2.2435 | Train Accuracy 0.5500 | Val Loss 3.0604 | Val Accuracy 0.3260
# Epoch 00020 | Train Loss 1.6344 | Train Accuracy 0.6100 | Val Loss 2.0696 | Val Accuracy 0.3100
# Epoch 00021 | Train Loss 1.2653 | Train Accuracy 0.5850 | Val Loss 1.3355 | Val Accuracy 0.5480
# Epoch 00022 | Train Loss 1.0602 | Train Accuracy 0.6600 | Val Loss 1.3480 | Val Accuracy 0.5960
# Epoch 00023 | Train Loss 1.2147 | Train Accuracy 0.5850 | Val Loss 1.7120 | Val Accuracy 0.5480
# Epoch 00024 | Train Loss 1.6995 | Train Accuracy 0.4750 | Val Loss 1.7312 | Val Accuracy 0.5300
# Epoch 00025 | Train Loss 1.9234 | Train Accuracy 0.4550 | Val Loss 1.5078 | Val Accuracy 0.5680
# Epoch 00026 | Train Loss 1.2774 | Train Accuracy 0.6400 | Val Loss 1.4192 | Val Accuracy 0.5500
# Epoch 00027 | Train Loss 1.0391 | Train Accuracy 0.7400 | Val Loss 1.4966 | Val Accuracy 0.4600
# Epoch 00028 | Train Loss 0.7620 | Train Accuracy 0.8050 | Val Loss 1.6385 | Val Accuracy 0.4480
# Epoch 00029 | Train Loss 0.8708 | Train Accuracy 0.7550 | Val Loss 1.8603 | Val Accuracy 0.3960
# Epoch 00030 | Train Loss 1.0184 | Train Accuracy 0.6800 | Val Loss 1.9236 | Val Accuracy 0.4180
# Epoch 00031 | Train Loss 0.9734 | Train Accuracy 0.6800 | Val Loss 1.8215 | Val Accuracy 0.4240
# Epoch 00032 | Train Loss 0.9514 | Train Accuracy 0.6750 | Val Loss 1.6623 | Val Accuracy 0.4140
# Epoch 00033 | Train Loss 0.8312 | Train Accuracy 0.7450 | Val Loss 1.5076 | Val Accuracy 0.4300
# Epoch 00034 | Train Loss 0.6986 | Train Accuracy 0.8000 | Val Loss 1.2862 | Val Accuracy 0.4980
# Epoch 00035 | Train Loss 0.6087 | Train Accuracy 0.8200 | Val Loss 0.9839 | Val Accuracy 0.6600
# Epoch 00036 | Train Loss 0.5042 | Train Accuracy 0.8800 | Val Loss 0.8042 | Val Accuracy 0.7500
# Epoch 00037 | Train Loss 0.5077 | Train Accuracy 0.8700 | Val Loss 0.7734 | Val Accuracy 0.7560
# Epoch 00038 | Train Loss 0.5467 | Train Accuracy 0.8250 | Val Loss 0.7550 | Val Accuracy 0.7540
# Epoch 00039 | Train Loss 0.6890 | Train Accuracy 0.7650 | Val Loss 0.7164 | Val Accuracy 0.7520
# Epoch 00040 | Train Loss 0.4898 | Train Accuracy 0.8300 | Val Loss 0.7256 | Val Accuracy 0.7340
# Epoch 00041 | Train Loss 0.4896 | Train Accuracy 0.8750 | Val Loss 0.7738 | Val Accuracy 0.7260
# Epoch 00042 | Train Loss 0.4460 | Train Accuracy 0.8900 | Val Loss 0.8117 | Val Accuracy 0.7200
# Epoch 00043 | Train Loss 0.4219 | Train Accuracy 0.8850 | Val Loss 0.8015 | Val Accuracy 0.7280
# Epoch 00044 | Train Loss 0.3523 | Train Accuracy 0.9100 | Val Loss 0.8048 | Val Accuracy 0.7460
# Epoch 00045 | Train Loss 0.3391 | Train Accuracy 0.8850 | Val Loss 0.8575 | Val Accuracy 0.7340
# Epoch 00046 | Train Loss 0.3434 | Train Accuracy 0.9200 | Val Loss 0.8905 | Val Accuracy 0.7040
# Epoch 00047 | Train Loss 0.3701 | Train Accuracy 0.8950 | Val Loss 0.9014 | Val Accuracy 0.6820
# Epoch 00048 | Train Loss 0.3434 | Train Accuracy 0.9100 | Val Loss 0.9079 | Val Accuracy 0.6820
# Epoch 00049 | Train Loss 0.3391 | Train Accuracy 0.9200 | Val Loss 0.8858 | Val Accuracy 0.7140
# Epoch 00050 | Train Loss 0.3248 | Train Accuracy 0.9050 | Val Loss 0.8007 | Val Accuracy 0.7400
# Epoch 00051 | Train Loss 0.2527 | Train Accuracy 0.9550 | Val Loss 0.7208 | Val Accuracy 0.7520
# Epoch 00052 | Train Loss 0.2224 | Train Accuracy 0.9550 | Val Loss 0.6709 | Val Accuracy 0.7720
# Epoch 00053 | Train Loss 0.2677 | Train Accuracy 0.9350 | Val Loss 0.6385 | Val Accuracy 0.7780
# Epoch 00054 | Train Loss 0.2346 | Train Accuracy 0.9500 | Val Loss 0.6060 | Val Accuracy 0.8000
# Epoch 00055 | Train Loss 0.1752 | Train Accuracy 0.9650 | Val Loss 0.6081 | Val Accuracy 0.7940
# Epoch 00056 | Train Loss 0.1840 | Train Accuracy 0.9800 | Val Loss 0.6391 | Val Accuracy 0.7800
# Epoch 00057 | Train Loss 0.2390 | Train Accuracy 0.9250 | Val Loss 0.6598 | Val Accuracy 0.7740
# Epoch 00058 | Train Loss 0.2225 | Train Accuracy 0.9400 | Val Loss 0.6373 | Val Accuracy 0.7780
# Epoch 00059 | Train Loss 0.2017 | Train Accuracy 0.9350 | Val Loss 0.6176 | Val Accuracy 0.7940
# Epoch 00060 | Train Loss 0.1730 | Train Accuracy 0.9650 | Val Loss 0.6373 | Val Accuracy 0.8100
# Epoch 00061 | Train Loss 0.2000 | Train Accuracy 0.9500 | Val Loss 0.6541 | Val Accuracy 0.7860
# Epoch 00062 | Train Loss 0.1879 | Train Accuracy 0.9350 | Val Loss 0.6939 | Val Accuracy 0.7660
# Epoch 00063 | Train Loss 0.1938 | Train Accuracy 0.9550 | Val Loss 0.7448 | Val Accuracy 0.7480
# Epoch 00064 | Train Loss 0.1684 | Train Accuracy 0.9650 | Val Loss 0.7630 | Val Accuracy 0.7420
# Epoch 00065 | Train Loss 0.1993 | Train Accuracy 0.9550 | Val Loss 0.7040 | Val Accuracy 0.7680
# Epoch 00066 | Train Loss 0.1605 | Train Accuracy 0.9600 | Val Loss 0.6563 | Val Accuracy 0.7680
# Epoch 00067 | Train Loss 0.1568 | Train Accuracy 0.9750 | Val Loss 0.6732 | Val Accuracy 0.7600
# Epoch 00068 | Train Loss 0.1392 | Train Accuracy 0.9550 | Val Loss 0.6640 | Val Accuracy 0.7660
# Epoch 00069 | Train Loss 0.1262 | Train Accuracy 0.9900 | Val Loss 0.6373 | Val Accuracy 0.7740
# Epoch 00070 | Train Loss 0.1307 | Train Accuracy 0.9800 | Val Loss 0.6504 | Val Accuracy 0.7800
# Epoch 00071 | Train Loss 0.1340 | Train Accuracy 0.9800 | Val Loss 0.6762 | Val Accuracy 0.7720
# Epoch 00072 | Train Loss 0.1136 | Train Accuracy 0.9750 | Val Loss 0.6692 | Val Accuracy 0.7740
# Epoch 00073 | Train Loss 0.1382 | Train Accuracy 0.9550 | Val Loss 0.6280 | Val Accuracy 0.7780
# Epoch 00074 | Train Loss 0.1266 | Train Accuracy 0.9800 | Val Loss 0.5944 | Val Accuracy 0.7980
# Epoch 00075 | Train Loss 0.1054 | Train Accuracy 1.0000 | Val Loss 0.5820 | Val Accuracy 0.7980
# Epoch 00076 | Train Loss 0.1265 | Train Accuracy 0.9800 | Val Loss 0.5786 | Val Accuracy 0.8060
# Epoch 00077 | Train Loss 0.1070 | Train Accuracy 0.9850 | Val Loss 0.5732 | Val Accuracy 0.7980
# Epoch 00078 | Train Loss 0.1033 | Train Accuracy 0.9850 | Val Loss 0.5980 | Val Accuracy 0.7940
# Epoch 00079 | Train Loss 0.1058 | Train Accuracy 0.9700 | Val Loss 0.6303 | Val Accuracy 0.7800
# Epoch 00080 | Train Loss 0.1114 | Train Accuracy 0.9850 | Val Loss 0.6354 | Val Accuracy 0.7800
# Epoch 00081 | Train Loss 0.1168 | Train Accuracy 0.9750 | Val Loss 0.6179 | Val Accuracy 0.7960
# Epoch 00082 | Train Loss 0.0833 | Train Accuracy 0.9950 | Val Loss 0.6149 | Val Accuracy 0.7840
# Epoch 00083 | Train Loss 0.0757 | Train Accuracy 1.0000 | Val Loss 0.6312 | Val Accuracy 0.7880
# Epoch 00084 | Train Loss 0.0965 | Train Accuracy 0.9850 | Val Loss 0.6439 | Val Accuracy 0.7840
# Epoch 00085 | Train Loss 0.0945 | Train Accuracy 0.9900 | Val Loss 0.6380 | Val Accuracy 0.7760
# Epoch 00086 | Train Loss 0.0952 | Train Accuracy 0.9850 | Val Loss 0.6226 | Val Accuracy 0.7820
# Epoch 00087 | Train Loss 0.0724 | Train Accuracy 1.0000 | Val Loss 0.6046 | Val Accuracy 0.7980
# Epoch 00088 | Train Loss 0.0672 | Train Accuracy 0.9950 | Val Loss 0.5853 | Val Accuracy 0.8040
# Epoch 00089 | Train Loss 0.0630 | Train Accuracy 0.9950 | Val Loss 0.5802 | Val Accuracy 0.8040
# Epoch 00090 | Train Loss 0.0627 | Train Accuracy 0.9900 | Val Loss 0.5703 | Val Accuracy 0.8140
# Epoch 00091 | Train Loss 0.0523 | Train Accuracy 1.0000 | Val Loss 0.5697 | Val Accuracy 0.8120
# Epoch 00092 | Train Loss 0.0771 | Train Accuracy 0.9850 | Val Loss 0.5871 | Val Accuracy 0.8020
# Epoch 00093 | Train Loss 0.0696 | Train Accuracy 0.9900 | Val Loss 0.6087 | Val Accuracy 0.7880
# Epoch 00094 | Train Loss 0.0756 | Train Accuracy 0.9850 | Val Loss 0.6277 | Val Accuracy 0.7800
# Epoch 00095 | Train Loss 0.0638 | Train Accuracy 0.9950 | Val Loss 0.6409 | Val Accuracy 0.7760
# Epoch 00096 | Train Loss 0.0691 | Train Accuracy 0.9900 | Val Loss 0.6396 | Val Accuracy 0.7800
# Epoch 00097 | Train Loss 0.0676 | Train Accuracy 0.9950 | Val Loss 0.6397 | Val Accuracy 0.7920
# Epoch 00098 | Train Loss 0.0642 | Train Accuracy 1.0000 | Val Loss 0.6413 | Val Accuracy 0.7840
# Epoch 00099 | Train Loss 0.0712 | Train Accuracy 0.9900 | Val Loss 0.6495 | Val Accuracy 0.7680
